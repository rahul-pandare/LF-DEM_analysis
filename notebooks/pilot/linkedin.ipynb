# %%
# for movie on linkedin

# %%
# importing libraries

import os
import glob
import matplotlib
import math
import numpy             as     np
import pandas            as     pd
import scipy.optimize    as     opt
from scipy.optimize import curve_fit
import matplotlib.pyplot as     plt
from   matplotlib        import font_manager
from   fractions         import Fraction
import pickle
import warnings
from prettytable import PrettyTable
from IPython.display import display, HTML 
warnings.filterwarnings('ignore', category=DeprecationWarning, module='mkl')

plt.rcParams.update({
  "figure.max_open_warning" : 0,
  "text.usetex"             : True,
  "text.latex.preamble"     : r"\usepackage{amsmath, bm, type1cm}",  # Added \bm for bold math
  "figure.autolayout"       : True,
  "font.family"             : "STIXGeneral",
  "mathtext.fontset"        : "stix",
  "font.size"               : 8,
  "xtick.labelsize"         : 8,
  "ytick.labelsize"         : 8,
  "lines.linewidth"         : 1,
  "lines.markersize"        : 5,
})
#plt.rcParams['text.latex.preamble']= r"\usepackage{amsmath}"
matplotlib.rc('text', usetex=True)
matplotlib.rcParams['text.latex.preamble'] = r'\boldmath'

colors = ['#4a91b5', '#e68139', '#5da258', '#87629b', '#1b9e77']

# %%
plt.figure(figsize=(4.687, 5))
workDir1='/media/rahul/rahul_2TB/high_bidispersity/new_data/flow_curves/stress_0.2r/NP_1000/phi_0.765/ar_1.4/Vr_0.5/run_1/' 
workDir2='/media/rahul/rahul_2TB/high_bidispersity/new_data/flow_curves/stress_10r/NP_1000/phi_0.765/ar_1.4/Vr_0.5/run_1/' 

savefig = '/home/rahul/City College Dropbox/Rahul Pandare/CUNY/research/bidisperse_project/manuscript/misc/linkedin_media/plot/'

dataFile1 = glob.glob(workDir1+"data_*.dat")[0] 
data1     = np.loadtxt(dataFile1)

values  = np.linspace(off, len(data[:,2]), 450)
values  = np.round(values).astype(int)

#for step in values:
visc1   = data1[off:,3] 
strain1 = data1[off:,1]

dataFile2 = glob.glob(workDir2+"data_*.dat")[0] 
data2 = np.loadtxt(dataFile2) 
visc2 = data2[off:,3] 
strain2 = data2[off:,1]

plt.plot(strain2, visc2, linestyle='-',color='r', linewidth=1.1, label=r'$\mathrm{At \;High \; Stress}$')
plt.plot(strain1, visc1, linestyle='-', color='#59A059', linewidth=1.5, label=r'$\mathrm{At \;Low \; Stress}$')

plt.yscale('log')
plt.xlabel(r'$\mathrm{Cumulative\; Strain}$', fontsize=12)
plt.ylabel(r'$\mathrm{Relative \; Viscosity}$', fontsize=12)
plt.legend(frameon=False, fontsize=10)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Optional: ticks only on left and bottom
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.tick_params(axis='both', labelsize=9)

#set lims
plt.xlim([0, 13])
plt.ylim([0.56e2, 3e3])
plt.legend(loc=(0.08, 0.35), borderpad=0.8,labelspacing=0.6)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(4.687, 5))
workDir1='/media/rahul/rahul_2TB/high_bidispersity/new_data/flow_curves/stress_0.2r/NP_1000/phi_0.765/ar_1.4/Vr_0.5/run_1/' 
workDir2='/media/rahul/rahul_2TB/high_bidispersity/new_data/flow_curves/stress_10r/NP_1000/phi_0.765/ar_1.4/Vr_0.5/run_1/' 

savefig = '/home/rahul/City College Dropbox/Rahul Pandare/CUNY/research/bidisperse_project/manuscript/misc/linkedin_media/plot/'

dataFile1 = glob.glob(workDir1+"data_*.dat")[0] 
data1     = np.loadtxt(dataFile1)

values  = np.linspace(off, len(data[:,2]), 450)
values  = np.round(values).astype(int)

for ii, step in enumerate(values):
    plt.cla()   # <<< clears axes (lines + legend), keeps figure

    visc1   = data1[off:step,3] 
    strain1 = data1[off:step,1]

    visc2   = data2[off:step,3]
    strain2 = data2[off:step,1]

    plt.plot(strain2, visc2, '-', color='r', linewidth=1.1,
             label=r'$\mathrm{At \;High \; Stress}$')
    plt.plot(strain1, visc1, '-', color='#59A059', linewidth=1.5,
             label=r'$\mathrm{At \;Low \; Stress}$')

    plt.yscale('log')
    plt.xlabel(r'$\mathrm{Cumulative\; Strain}$', fontsize=12)
    plt.ylabel(r'$\mathrm{Relative \; Viscosity}$', fontsize=12)

    plt.xlim([0, 13])
    plt.ylim([0.56e2, 3e3])

    plt.legend(loc=(0.08, 0.35), frameon=False, fontsize=10,
           borderpad=0.8, labelspacing=0.6)
    
    ax = plt.gca()
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(axis='both', labelsize=9)

    plt.tight_layout()
    plt.savefig(f'{savefig}/{ii}.png', dpi=300, bbox_inches="tight")

#plt.show()

# %%
values  = np.linspace(off, len(data[:,2]), 450)
values  = np.round(values).astype(int)

# %%
values
# Out:
# array([ 100,  102,  105,  107,  110,  112,  115,  117,  120,  122,  125,
#         127,  129,  132,  134,  137,  139,  142,  144,  147,  149,  151,
#         154,  156,  159,  161,  164,  166,  169,  171,  174,  176,  178,
#         181,  183,  186,  188,  191,  193,  196,  198,  201,  203,  205,
#         208,  210,  213,  215,  218,  220,  223,  225,  228,  230,  232,
#         235,  237,  240,  242,  245,  247,  250,  252,  254,  257,  259,
#         262,  264,  267,  269,  272,  274,  277,  279,  281,  284,  286,
#         289,  291,  294,  296,  299,  301,  304,  306,  308,  311,  313,
#         316,  318,  321,  323,  326,  328,  330,  333,  335,  338,  340,
#         343,  345,  348,  350,  353,  355,  357,  360,  362,  365,  367,
#         370,  372,  375,  377,  380,  382,  384,  387,  389,  392,  394,
#         397,  399,  402,  404,  407,  409,  411,  414,  416,  419,  421,
#         424,  426,  429,  431,  433,  436,  438,  441,  443,  446,  448,
# ...
